# %%
#clone the voxelnet git repo
# !git clone https://github.com/gkadusumilli/Voxelnet.git
#change the cwd
# %cd /content/drive/MyDrive/Voxelnet/crop_data
# Out:
# Cloning into 'Voxelnet'...
# remote: Enumerating objects: 91, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 91 (delta 2), reused 1 (delta 0), pack-reused 80
# Unpacking objects: 100% (91/91), 1.24 MiB | 987.00 KiB/s, done.
# /content/drive/MyDrive/Voxelnet/crop_data

# %%
#Data label file
# !wget https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_calib.zip   #Calib file
# !wget https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_velodyne.zip  #Velodyne file
# !wget https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_image_2.zip   # Image file
# !wget https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_label_2.zip
# Out:
# --2023-06-13 00:18:08--  https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_calib.zip
# Resolving s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)... 52.219.46.87
# Connecting to s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)|52.219.46.87|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 26854811 (26M) [application/zip]
# Saving to: ‘data_object_calib.zip’
#
# data_object_calib.z 100%[===================>]  25.61M  9.87MB/s    in 2.6s
#
# 2023-06-13 00:18:11 (9.87 MB/s) - ‘data_object_calib.zip’ saved [26854811/26854811]
#
# --2023-06-13 00:18:11--  https://s3.eu-central-1.amazonaws.com/avg-kitti/data_object_velodyne.zip
# Resolving s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)... 52.219.46.87
# Connecting to s3.eu-central-1.amazonaws.com (s3.eu-central-1.amazonaws.com)|52.219.46.87|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 28750710812 (27G) [application/zip]
# ...

# %%
# %cd /content/drive/MyDrive/Voxelnet
# Out:
# /content/drive/MyDrive/Voxelnet

# %%
#Unzip the velodyne training folder
# !unzip data_object_velodyne.zip 'training/*' -d /content/drive/MyDrive/Voxelnet/crop_data

# %%
#Unzip the image training folder
# !unzip data_object_image_2.zip 'training/*' -d /content/drive/MyDrive/Voxelnet/crop_data
#unzip the object label
# !unzip data_object_label_2.zip 'training/*' -d /content/drive/MyDrive/Voxelnet/crop_data
#unzip the data object calib
# !unzip data_object_calib.zip 'training/*' -d /content/drive/MyDrive/Voxelnet/crop_data

# %%
# %cd /content

# !pip install --upgrade scipy
# Out:
# /content
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# %cd /content/drive/MyDrive/Voxelnet/crop_data
# Out:
# /content/drive/MyDrive/Voxelnet/crop_data

# %%
#to run the 'crop.py' lower version of scipy is needed
# !pip install scipy==1.1.0

#run crop.py
# !python crop.py
# Out:
# /content/drive/MyDrive/Voxelnet/crop_data/crop.py:58: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imread(img_dir)

# %%
#create a folder 'validation' and copy the content in training
#folder
# %cd /content
# !mkdir /content/drive/MyDrive/Voxelnet/crop_data/validation
# %cp -av /content/drive/MyDrive/Voxelnet/crop_data/training /content/drive/MyDrive/Voxelnet/crop_data/validation/
# Out:
# Streaming output truncated to the last 5000 lines.
# '/content/drive/MyDrive/Voxelnet/crop_data/training/calib/002481.txt' -> '/content/drive/MyDrive/Voxelnet/crop_data/validation/training/calib/002481.txt'
# '/content/drive/MyDrive/Voxelnet/crop_data/training/calib/002482.txt' -> '/content/drive/MyDrive/Voxelnet/crop_data/validation/training/calib/002482.txt'
# '/content/drive/MyDrive/Voxelnet/crop_data/training/calib/002483.txt' -> '/content/drive/MyDrive/Voxelnet/crop_data/validation/training/calib/002483.txt'
# '/content/drive/MyDrive/Voxelnet/crop_data/training/calib/002484.txt' -> '/content/drive/MyDrive/Voxelnet/crop_data/validation/training/calib/002484.txt'
# '/content/drive/MyDrive/Voxelnet/crop_data/training/calib/002485.txt' -> '/content/drive/MyDrive/Voxelnet/crop_data/validation/training/calib/002485.txt'
# '/content/drive/MyDrive/Voxelnet/crop_data/training/calib/002486.txt' -> '/content/drive/MyDrive/Voxelnet/crop_data/validation/training/calib/002486.txt'
# ...

# %%
import os

lines_train = [line.rstrip('\n') for line in open('/content/drive/MyDrive/Voxelnet/crop_data/train.txt')]
lines_val = [line.rstrip('\n') for line in open('/content/drive/MyDrive/Voxelnet/crop_data/val.txt')]

for i in lines_train:

  os.remove('/content/drive/MyDrive/Voxelnet/crop_data/training/image_2/'+i+'.png')
  os.remove('/content/drive/MyDrive/Voxelnet/crop_data/training/label_2/'+i+'.txt')
  os.remove('/content/drive/MyDrive/Voxelnet/crop_data/training/velodyne/'+i+'.bin')

for i in lines_val:

  os.remove('/content/drive/MyDrive/Voxelnet/crop_data/validation/image_2/'+i+'.png')
  os.remove('/content/drive/MyDrive/Voxelnet/crop_data/validation/label_2/'+i+'.txt')
  os.remove('/content/drive/MyDrive/Voxelnet/crop_data/validation/velodyne/'+i+'.bin')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-dc11f2d85453> in <cell line: 6>()
#       6 for i in lines_train:
#       7
# ----> 8   os.remove('/content/drive/MyDrive/Voxelnet/crop_data/training/image_2/'+i+'.png')
#       9   os.remove('/content/drive/MyDrive/Voxelnet/crop_data/training/label_2/'+i+'.txt')
#      10   os.remove('/content/drive/MyDrive/Voxelnet/crop_data/training/velodyne/'+i+'.bin')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Voxelnet/crop_data/training/image_2/000000.png'

# %%
# !zip -r '/content/drive/MyDrive/Voxelnet/data/data_lidar.zip' '/content/drive/MyDrive/Voxelnet/crop_data'
# Out:
# Streaming output truncated to the last 5000 lines.
# zip warning: No such file or directory
# 	zip warning: could not open for reading: content/drive/MyDrive/Voxelnet/crop_data/training/velodyne/792.bin
#   adding: content/drive/MyDrive/Voxelnet/crop_data/training/velodyne/793.bin
# zip warning: No such file or directory
# 	zip warning: could not open for reading: content/drive/MyDrive/Voxelnet/crop_data/training/velodyne/793.bin
#   adding: content/drive/MyDrive/Voxelnet/crop_data/training/velodyne/794.bin
# zip warning: No such file or directory
# 	zip warning: could not open for reading: content/drive/MyDrive/Voxelnet/crop_data/training/velodyne/794.bin
#   adding: content/drive/MyDrive/Voxelnet/crop_data/training/velodyne/795.bin
# zip warning: No such file or directory
# 	zip warning: could not open for reading: content/drive/MyDrive/Voxelnet/crop_data/training/velodyne/795.bin
#   adding: content/drive/MyDrive/Voxelnet/crop_data/training/velodyne/796.bin
# ...
